# %%
x = 3
y = 4
print(x + y)
# Out:
# 7

# %%
list4 = [1,2,3,4,5]
for i in list4:
    if i%2==0:
        print(f"{i} is an Even Number")
# Out:
# 2 is an Even Number
# 4 is an Even Number

# %%
Name = "Yasmin"
Height = 5.4
Age = 20
Yasmin_List = [1,4,5,6,2,7,8,9,20,21]
Yasmin_Dict = {
    "Roll_no":38,
    "Branch" : "cse",
    "cgpa" : 8.7,
    "Section":"B",
    "Above_18": True
}

# %%
print("Name: ",Name)
print("Height: ",Height)
print("Age: ",Age)
print("List: ",Yasmin_List)
print("Dict: ",Yasmin_Dict)
# Out:
# Name:  Yasmin
# Height:  5.4
# Age:  20
# List:  [1, 4, 5, 6, 2, 7, 8, 9, 20, 21]
# Dict:  {'Roll_no': 38, 'Branch': 'cse', 'cgpa': 8.7, 'Section': 'B', 'Above_18': True}

# %%
print(type(Name))
print(type(Height))
print(type(Age))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>
