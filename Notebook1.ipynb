# %%
x = 3
y = 4
print(x + y)
# Out:
# 7

# %%
college_name="jhulelal"
postal_code= 441111
cgpa= 7.9
is_cse= True

print(f"college:{college_name}")
print(f"code:{postal_code}")
print(f"cgpa:{cgpa}")
print(f"cse:{is_cse}")

lista=["Arif",22,7.2,"cse"]

Student = {
    "Name":"Arif",
    "age":22,
    "cgpa":7.2,
    "is_student":True
}

print(lista)
print(Student)

bill= float(input("total price:"))

if bill >= 10000:
         Discount_1=bill * 0.20 
         total_price_1= bill- Discount_1
         print(f"FInal Price:{total_price_1}")


elif bill >= 5000 :
        Discount_2= bill * 0.10
        total_price_2= bill - Discount_2
        print(f"total_price:{total_price_2}")

elif bill < 5000 :
        Discount_3= bill * 0.8
        total_price_3= bill - Discount_3
        print (f"total price:{total_price_3}")

else :
        print(f"total price:{bill}")
