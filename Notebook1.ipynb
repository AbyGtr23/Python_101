# %%
x = 3
y = 4
print(x + y)
# Out:
# 7

# %%
college_name="jhulelal"
postal_code= 441111
cgpa= 7.9
is_cse= True

print(f"college:{college_name}")
print(f"code:{postal_code}")
print(f"cgpa:{cgpa}")
print(f"cse:{is_cse}")

lista=["Arif",22,7.2,"cse"]

Student = {
    "Name":"Arif",
    "age":22,
    "cgpa":7.2,
    "is_student":True
}

print(lista)
print(Student)
