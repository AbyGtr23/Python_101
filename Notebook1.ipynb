# %%
x = 3
y = 4
print(x + y)
# Out:
# 7

# %%
print("Abhay")
# Out:
# Abhay

# %%
name='Abhay Gomkale'
age=21
height=5.7

# %%
Abhaymarks=[30,25,29,28,30,20,21,31,12,96]

# %%
Abhay={
    "Name":"Abhay",
    "Class":"3rd Year",
    "UID":"UGF23CS077",
    "Subject":"Data Science"
}

# %%
print("Name of the student is",name)
print("His age is",age)
print("Height is",height)
# Out:
# Name of the student is Abhay Gomkale
# His age is 21
# Height is 5.7

# %%
print("List of marks",Abhaymarks)
# Out:
# List of marks [30, 25, 29, 28, 30, 20, 21, 31, 12, 96]

# %%
print("His dictionary or his more info ",Abhay)
# Out:
# His dictionary or his more info  {'Name': 'Abhay', 'Class': '3rd Year', 'UID': 'UGF23CS077', 'Subject': 'Data Science'}
