# %%
print('My STudents are learning DS')
# Out:
# My STudents are learning DS

# %%
user_name = input("Enter your name:")
try:
    user_age = int(input("please enter you age"))
    if user_age <18:
        print(f"{user_name} is a minor")
    else:
        print(f"{user_name} is an adult")
except ValueError:
    print("Enter a valid age. Invalid entry!!")
# Out:
# Enter a valid age. Invalid entry!!

# %%
# You are writing a Python program that processes user inputs 
# and performs a mathematical operation. 
# The program attempts to:
# Convert two string inputs into integers.
# Perform a division operation using the converted values.
# Handle possible runtime errors using try-except.
# However, the inputs may contain invalid numeric values, 
# or the program may attempt an illegal 
# mathematical operation (such as division by zero)

# %%
# TASK#2

# Write a Python program that processes a sequence of 
# numbers entered by the user. 
# The program should demonstrate the use of exception handling, 
# conditional statements, control statements, iteration, 
# and sequence data types.

# Requirements
# Ask the user to enter a list of numbers separated by spaces.
# Store these numbers in a sequence data type (such as a list).
# Use a loop (iteration) to go through each number in the list.
# For each number:
# Use try and except to handle cases where the input cannot be 
# converted into an integer.
# If the conversion is successful, use conditional statements to check:
# If the number is even, print "Even number".
# If the number is odd, print "Odd number".
# If an invalid value (like text) is encountered, 
# the program should display "Invalid input detected" and 
# continue processing the remaining elements.
# After processing all numbers, display:
# The total count of valid numbers
# The total count of invalid inputs

# %%
#TASK 3
# Problem Statement
scores = [78, 40, 92, 34, 67, 88, 53, 41, 76, 29, 64, 81, 39, 55, 72, 90, 47, 68, 33, 84, 0, -5, 100, 40, 75]
# A teacher has recorded the scores of 20 students in a Python list. 
# Your task 
# is to write a program that performs several operations on this list.

# SUB-TASKS:
#1. Create a list named scores containing 20 integer values 
# representing student marks.

#2. Use slicing to create:
# A list containing the first 10 scores.
# A list containing the last 5 scores.
# A list containing every second score from the original list.

#3. Use iteration (for loop) to:
# Print each score along with whether the student Passed (≥ 40) or Failed (< 40).
#4. Use list comprehension to create:
# A list of all passing scores.
# A list of all scores increased by 5 marks (bonus marks).
# A list containing only the scores greater than 75.
#5. Display:
# The number of students who passed.
# The number of students who failed.
