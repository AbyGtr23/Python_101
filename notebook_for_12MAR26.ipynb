# %%
#You are a junior data analyst working for a small retail store. 
# The store manager has provided the daily sales values for one week, 
# but the values are stored as text (strings) 
# instead of numbers. Your task is to write a Python program to process and analyze this data

sales_data = ["1200", "1500", "1100", "1800", "1600", "1400", "1700"]

# %%
# Out:
# [1200, 1500, 1100, 1800, 1600, 1400, 1700]
# ['1200', '1500', '1100', '1800', '1600', '1400', '1700']

# %%
# for i, sale in enumerate(sales_numbers, start=1):
#     print(f"day {i}")

pairs = enumerate(sales_num, start=1)
print(dict(pairs))
# Out:
# {1: 1200, 2: 1500, 3: 1100, 4: 1800, 5: 1600, 6: 1400, 7: 1700}
