# %%
while True:
    num = int(input("Enter a number: "))

    if num == 9:
        print("THIS IS END THE PROGRAM")
        break
    else:
        print("Continue... Enter again")
# Out:
# Continue... Enter again
# Continue... Enter again
# THIS IS END THE PROGRAM

# %%
def Animal():
    while True:
        animal = (input("Enter the name of the animal :"))
        if animal == "Elephent":
            print("Stop")
            break

        elif animal == "Cat":
            print("This is cat")

        elif animal == "Dog":
            print("This is Dog")

        else :
            print("Continue... Enter again")

# # function call
Animal()
# Out:
# Continue... Enter again
# Continue... Enter again
# Stop

# %%
# white a python program that uses the 'for' loop for 
# iterating through list of elemnts and
# prints all the element present in that list

list = [1,"pragti",2.12,"nagpur"]
number = len(list)
for i in range(number):
    print(f"Element in {i} Position of the list : {list[i]}")
# Out:
# Element in 0 Position of the list : 1
# Element in 1 Position of the list : pragti
# Element in 2 Position of the list : 2.12
# Element in 3 Position of the list : nagpur

# %%
new_dict ={"item1": "pen" ,"item2" : "pencile","item3": "Ereser"}
for i,j in new_dict.items():
    print(f"{i}:{j}")
# Out:
# item1:pen
# item2:pencile
# item3:Ereser

# %%
# defiene a list and define the search atom

list_items = {1,2,3,4,5,6,7,8}
search_atom = 7
for i in list_items:
    if i == search_atom:
        break
    else:
        print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
# use append function in the list
# use the extend & insert function in the list 
# observe the difference in the outputs afterwards

# original list
List = [10, 20, 30]
print("Original List =", L)

# 1️⃣ append() → single element add karta hai end me
List.append(40)
print("After append =", List)

# 2️⃣ extend() → dusri list ke sab elements add karta hai
M = [50, 60]
List.extend(M)
print("After extend =", List)

# 3️⃣ insert() → specific position pe element add karta hai
List.insert(1, 15)
print("After insert =", List)
# Out:
# Original List = [10, 15, 20, 30, 40, 50, 60]
# After append = [10, 20, 30, 40]
# After extend = [10, 20, 30, 40, 50, 60]
# After insert = [10, 15, 20, 30, 40, 50, 60]

# %%
# populate the list with the squre of the number between 1-12
list = []
for num in range (1,13):
    square = num * num
    list.append(square)

# display result
print("List of squares =", list)
# Out:
# List of squares = [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144]

# %%
list = []
for i in range (1,13):
    list.append(i*i)

print(list)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144]

# %%
list_of_sqr = [x * x for x in range(1,13)]
list_of_sqr
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144]

# %%
# use the sort(),pop(),remove() fumction in the list of squere that have created
my_list = [10, 20, 30, 40, 50]
my_list.sort()
print("After sort() =", my_list)
my_list.remove(30)
print("After remove(30) =", my_list)
my_list.pop(1)
print("After pop(1) =", my_list)
# Out:
# After sort() = [10, 20, 30, 40, 50]
# After remove(30) = [10, 20, 40, 50]
# After pop(1) = [10, 40, 50]
