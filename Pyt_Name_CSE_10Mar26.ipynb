# %%
print('Hello CSE People')
# Out:
# Hello CSE People

# %%
x = 3+4*78
print(x)
# Out:
# 315

# %%
x = 4
name = 'Ronit'
#Convert the inteeger data to string
x_str = str(x)
data_type = type(x_str)
data_type
# Out:
# str
