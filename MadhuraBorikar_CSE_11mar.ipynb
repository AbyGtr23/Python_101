# %%
scores = [78, 40, 92, 34, 67, 88, 53, 41, 76, 29, 64, 81, 39, 55, 72, 90, 47, 68, 33, 84, 0, -5, 100, 40, 75]

score_passed = []
score_failed =[]


first_10_scores = scores[0:10]
print(first_10_scores)

print(scores[-5:])

print(scores[1::2])


# checking if passed or failed
for score in scores:
    if score >= 40:
        score_passed.append(score)
    else:
        score_failed.append(score)


# Incresed by 5
increased_by_5 = []
for score in scores:
    score+=5
    increased_by_5.append(score)


greater_than_75 =[]
# Greater than 75
for score in scores:
    if score > 75:
        greater_than_75.append(score)




# print(increased_by_5)  
print(score_passed)
print(score_failed)

# print(greater_than_75)
# Out:
# [78, 40, 92, 34, 67, 88, 53, 41, 76, 29]
# [0, -5, 100, 40, 75]
# [40, 34, 88, 41, 29, 81, 55, 90, 68, 84, -5, 40]
# [78, 40, 92, 67, 88, 53, 41, 76, 64, 81, 55, 72, 90, 47, 68, 84, 100, 40, 75]
# [34, 29, 39, 33, 0, -5]
# [78, 92, 88, 76, 81, 90, 84, 100]
