# %%
def numberspecification():
    input1=int(input("enter a number between 1 to 10"))
    while input1!= 3:
      if input1==1:
         print("this is dog")
           
      elif input1==2:
         print("this is cat") 
        
      else:
        print("This is not animal")
        break

# %%
numberspecification()

# %%
list=[1,2,3,"yash",45,False,True]
number=len(list)

for i in range(number):
    print(f"eliment in {i} position of list : {list[i]}")
# Out:
# eliment in 0 position of list : 1
# eliment in 1 position of list : 2
# eliment in 2 position of list : 3
# eliment in 3 position of list : yash
# eliment in 4 position of list : 45
# eliment in 5 position of list : False
# eliment in 6 position of list : True

# %%
#use the sort(), remove(),pop(),funtion in the list of squares
# that you have created .
my_list = [10, 20, 30, 40, 50]
my_list.sort()
print("After sort() =", my_list)
my_list.remove(30)
print("After remove(30) =", my_list)
my_list.pop(1)
print("After pop(1) =", my_list)
# Out:
# After sort() = [10, 20, 30, 40, 50]
# After remove(30) = [10, 20, 40, 50]
# After pop(1) = [10, 40, 50]

# %%
new_dict = {"Item1": "pen","Iteam2": "pencil", "iteam3":"eraser"} 

for i,j in new_dict.items():
  
     print(f"{i}: {j}")
# Out:
# Item1: pen
# Iteam2: pencil
# iteam3: eraser

# %%
# define a list and define a variable name search item
list=[1,2,3,45,66,74,84,87,90]
search_iteam=45
for i in list:
        if i==search_iteam:
            print("iteam found")
            # break
            continue
        else:
            print(i)
# Out:
# 1
# 2
# 3
# iteam found
# 66
# 74
# 84
# 87
# 90

# %%
l=[]

input1=input("enter a number")

l.append(input1)
   
print(l)


l.insert(0,45)
print(l)

l.extend([1,2,3])
print(l)
# Out:
# ['4']
# [45, '4']
# [45, '4', 1, 2, 3]

# %%
# populate the list with the squre of the number between 1-12
list = []
for num in range (1,13):
    square = num * num
    list.append(square)

# display result
print("List of squares =", list)
# Out:
# List of squares = [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144]

# %%
list_of_sqr = [x * x for x in range(1,13)]
list_of_sqr
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144]
