# %% [markdown]
# Discount and Payable amount

# %%
Price=float(input("Enter the amount of object."))
if Price >= 5005:
    disc=Price*0.16
elif Price >=1000:
    disc=Price*0.10
elif Price >=500:
    disc=Price*0.06
total=Price-disc
    
print("The payable amount is",total)
# Out:
# The payable amount is 8450.4
