# %%
fruits=["apple", "apricot", "banana","banana","apple", "orange","orange","grapes","grapes"]
print(fruits)
unique_list=set(fruits)
print(list(unique_list))
# Out:
# ['apple', 'apricot', 'banana', 'banana', 'apple', 'orange', 'orange', 'grapes', 'grapes']
# ['apricot', 'orange', 'apple', 'banana', 'grapes']

# %%
a=225 #find sqrt of a
print(a**0.5)
# Out:
# 15.0
