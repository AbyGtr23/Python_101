# %%
x= 45
print(x)
print(type(x))
# Out:
# 45
# <class 'int'>

# %%
fruits = ["apple", "Banana", "kiwi", "coconut", "walnut", "Guava", "Peach"]
#Use append() to add the following fruits to the list:
#Grapes, Strawberry, Orange

#Use remove() to remove 'walnut' from the list

#Use extend() to add a list of items of your choice.

# %%
fruits.append(['a', 'b'])
fruits
fruits.extend(['gooseberry', 'strawberry'])
fruits
# Out:
# ['apple',
#  'Banana',
#  'kiwi',
#  'coconut',
#  'walnut',
#  'Guava',
#  'Peach',
#  ['a', 'b'],
#  'gooseberry',
#  'strawberry']
