# %%
i = input("Enter value1:")
j = input("Enter value2:")
try:
   value1=int(i)
   value2=int(j)
   v= value1/value2
   print(f"answer is {v}")
except ZeroDivisionError:
   
   print("Enter a valid value")
# Out:
# Enter a valid value

# %% [markdown]
# write a program that processors a sequence of numbers entered by the users the program should demonstratethe use of exception handling conditional statement,control statement, iteration ,and sequence data types

# %%
i= input("Enter sequence of number: ")
num = i.split()
valid_count = 0
invalid_count = 0
for j in num:
    try:
        n=int(j)
        valid_count += 1
        if n%2==0:
            print(f"{n} is even number")
        else:
            print(f"{n} is odd number")

    except (TypeError,ValueError):
        print("invalid input")
        invalid_count +=1           

print("\nTotal valid numbers:", valid_count)
print("Total invalid inputs:", invalid_count)
# Out:
# 55 is odd number
# 56 is even number
# invalid input
# 89 is odd number
#
# Total valid numbers: 3
# Total invalid inputs: 1
